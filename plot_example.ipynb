# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
log = np.load("attack_log.npy")
print(log)
plt.plot(log[:,1],log[:,0])
plt.xlim(0,50000)
plt.ylabel('Distortion')
plt.xlabel('Num of queries')
plt.show()
plt.savefig('books_read.png')
# Out:
# [[6.4063883e+00 3.0400000e+02]
#  [6.4063883e+00 4.7000000e+02]
#  [5.6698380e+00 7.3320001e+02]
#  ...
#  [1.2551543e+00 8.0392602e+04]
#  [1.2551543e+00 8.0392602e+04]
#  [1.2551543e+00 8.0392602e+04]]
